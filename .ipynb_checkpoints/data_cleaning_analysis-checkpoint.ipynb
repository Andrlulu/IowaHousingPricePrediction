# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# display all columns of dataframe
pd.set_option('display.max_columns', 500)

# Suppress warning
import warnings
warnings.filterwarnings('ignore')

# %%
train_df = pd.read_csv('./data/train.csv', index_col = 0)
test_df = pd.read_csv('./data/test.csv', index_col = 0)

full_data = [train_df, test_df]

combine = pd.concat(full_data)
combine_c = combine.copy()

# %%
##
# train_df.groupby(['TotRmsAbvGrd', 'no_of_fl']).mean()['SalePrice']

# %%
# def check_flrs(flSF):
#     if flSF == 0:
#         return 1
#     else:
#         return 2
    
    
# train_df = train_df.assign(no_of_fl = train_df['2ndFlrSF'].apply(check_flrs))

# %%
print(train_df.shape)
print(test_df.shape)
print(combine_c.shape)
# Out:
# (1460, 80)
# (1459, 79)
# (2919, 80)

# %%
combine_c.columns
# Out:
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'Alley', 'BedroomAbvGr',
#        'BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtFinType1', 'BsmtFinType2', 'BsmtFullBath', 'BsmtHalfBath',
#        'BsmtQual', 'BsmtUnfSF', 'CentralAir', 'Condition1', 'Condition2',
#        'Electrical', 'EnclosedPorch', 'ExterCond', 'ExterQual', 'Exterior1st',
#        'Exterior2nd', 'Fence', 'FireplaceQu', 'Fireplaces', 'Foundation',
#        'FullBath', 'Functional', 'GarageArea', 'GarageCars', 'GarageCond',
#        'GarageFinish', 'GarageQual', 'GarageType', 'GarageYrBlt', 'GrLivArea',
#        'HalfBath', 'Heating', 'HeatingQC', 'HouseStyle', 'KitchenAbvGr',
#        'KitchenQual', 'LandContour', 'LandSlope', 'LotArea', 'LotConfig',
#        'LotFrontage', 'LotShape', 'LowQualFinSF', 'MSSubClass', 'MSZoning',
#        'MasVnrArea', 'MasVnrType', 'MiscFeature', 'MiscVal', 'MoSold',
#        'Neighborhood', 'OpenPorchSF', 'OverallCond', 'OverallQual',
#        'PavedDrive', 'PoolArea', 'PoolQC', 'RoofMatl', 'RoofStyle',
#        'SaleCondition', 'SalePrice', 'SaleType', 'ScreenPorch', 'Street',
#        'TotRmsAbvGrd', 'TotalBsmtSF', 'Utilities', 'WoodDeckSF', 'YearBuilt',
#        'YearRemodAdd', 'YrSold'],
#       dtype='object')

# %% [markdown]
# # Seperating Columns

# %%
cat_features = combine.dtypes[combine.dtypes == 'object'].index
num_features = combine.dtypes[combine.dtypes != 'object'].index
print(cat_features)
print(num_features)
# Out:
# Index(['Alley', 'BldgType', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1',
#        'BsmtFinType2', 'BsmtQual', 'CentralAir', 'Condition1', 'Condition2',
#        'Electrical', 'ExterCond', 'ExterQual', 'Exterior1st', 'Exterior2nd',
#        'Fence', 'FireplaceQu', 'Foundation', 'Functional', 'GarageCond',
#        'GarageFinish', 'GarageQual', 'GarageType', 'Heating', 'HeatingQC',
#        'HouseStyle', 'KitchenQual', 'LandContour', 'LandSlope', 'LotConfig',
#        'LotShape', 'MSZoning', 'MasVnrType', 'MiscFeature', 'Neighborhood',
#        'PavedDrive', 'PoolQC', 'RoofMatl', 'RoofStyle', 'SaleCondition',
#        'SaleType', 'Street', 'Utilities'],
#       dtype='object')
# Index(['1stFlrSF', '2ndFlrSF', '3SsnPorch', 'BedroomAbvGr', 'BsmtFinSF1',
#        'BsmtFinSF2', 'BsmtFullBath', 'BsmtHalfBath', 'BsmtUnfSF',
#        'EnclosedPorch', 'Fireplaces', 'FullBath', 'GarageArea', 'GarageCars',
#        'GarageYrBlt', 'GrLivArea', 'HalfBath', 'KitchenAbvGr', 'LotArea',
#        'LotFrontage', 'LowQualFinSF', 'MSSubClass', 'MasVnrArea', 'MiscVal',
#        'MoSold', 'OpenPorchSF', 'OverallCond', 'OverallQual', 'PoolArea',
#        'SalePrice', 'ScreenPorch', 'TotRmsAbvGrd', 'TotalBsmtSF', 'WoodDeckSF',
#        'YearBuilt', 'YearRemodAdd', 'YrSold'],
#       dtype='object')

# %%
cat_extra = ['MSSubClass', 'OverallCond', 'OverallQual']
combine[cat_extra] = combine[cat_extra].astype('object')

# %%
cat_features = combine.dtypes[combine.dtypes == 'object'].index
num_features = combine.dtypes[combine.dtypes != 'object'].index
#print(cat_features)
#print(num_features)
print('No of categorical features',len(cat_features))
print('No of numerical features',len(num_features))
# Out:
# No of categorical features 46
# No of numerical features 34

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Check for NAs

# %%
# to check Nans in  df
mask_tr = combine.isna().sum()
mask_tr[mask_tr>0]
# Out:
# Alley           2721
# BsmtCond          82
# BsmtExposure      82
# BsmtFinSF1         1
# BsmtFinSF2         1
# BsmtFinType1      79
# BsmtFinType2      80
# BsmtFullBath       2
# BsmtHalfBath       2
# BsmtQual          81
# BsmtUnfSF          1
# Electrical         1
# Exterior1st        1
# Exterior2nd        1
# Fence           2348
# FireplaceQu     1420
# Functional         2
# GarageArea         1
# GarageCars         1
# GarageCond       159
# GarageFinish     159
# GarageQual       159
# GarageType       157
# GarageYrBlt      159
# KitchenQual        1
# LotFrontage      486
# MSZoning           4
# MasVnrArea        23
# MasVnrType        24
# MiscFeature     2814
# PoolQC          2909
# SalePrice       1459
# SaleType           1
# TotalBsmtSF        1
# Utilities          2
# dtype: int64

# %% [markdown]
# # Impute Function

# %%
# define function to impute missing value
def impute_missing(dfName):
    
    # impute Continous numeric Variables   
    dfName['GarageYrBlt'] = dfName['GarageYrBlt'].fillna(min(dfName['GarageYrBlt']))
    dfName['LotFrontage'] = dfName.groupby("Neighborhood")["LotFrontage"].transform(lambda x: x.fillna(x.median()))
    
    # impute 0
    for col in num_features:
        dfName[col].fillna(0, inplace = True)
    
    dfName['Functional'] = dfName['Functional'].fillna('Typ')
    
   # impute categorical variable missing not at Random with the mode value  
    for col in ('Electrical','MSZoning' , 'Exterior1st', 'Exterior2nd','KitchenQual', 'SaleType'):
        dfName[col].fillna(dfName[col].mode()[0], inplace = True)
  
    # impute None
    for col in cat_features:
        dfName[col].fillna('None', inplace = True)

# %%
#impute
impute_missing(combine)

# %%
# to check Nans after imputing
mask_tr = combine.isna().sum()
mask_tr[mask_tr>0]
# Out:
# Series([], dtype: int64)

# %%
combine.SalePrice.sample(6)
# Out:
# Id
# 987     117000.0
# 630     168500.0
# 2082         0.0
# 2799         0.0
# 1755         0.0
# 878     350000.0
# Name: SalePrice, dtype: float64

# %% [markdown]
# # Dummify

# %%
combine = pd.get_dummies(combine, drop_first=True)

# %%
combine.sample(6)
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# Id
# 274       1632         0          0             3       620.0       620.0
# 1645      1621         0          0             3      1333.0       168.0
# 1318      1352         0          0             2         0.0         0.0
# 873        910         0          0             3         0.0         0.0
# 925       1686         0          0             3       625.0      1061.0
# 2215       912         0          0             2         0.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  Fireplaces
    0                     0                     0
#
#       Neighborhood_StoneBr  Neighborhood_Timber  Neighborhood_Veenker  \
# Id
# 274                      0                    0                     0
# 1645                     0                    0                     0
# 1318                     0                    0                     0
# 873                      0                    0                     0
# 925                      0                    0                     0
# 2215                     0                    0                     0
#
#       PavedDrive_P  PavedDrive_Y  PoolQC_Fa  PoolQC_Gd  PoolQC_None  \
# Id
# 274              0             1          0          0            1
# 1645             0             1          0          0            1
# 1318             0             1          0          0            1
# 873              0             1          0          0            1
# 925              0             1          0          0            1
# 2215             0             1          0          0            1
#
#       RoofMatl_CompShg  RoofMatl_Membran  RoofMatl_Metal  RoofMatl_Roll  \
# Id
# 274                  1                 0               0              0
# 1645                 1                 0               0              0
# 1318                 1                 0               0              0
# 873                  1                 0               0              0
# 925                  1                 0               0              0
# 2215                 1                 0               0              0
#
#       RoofMatl_Tar&Grv  RoofMatl_WdShake  RoofMatl_WdShngl  RoofStyle_Gable  \
# Id
# 274                  0                 0                 0                0
# 1645                 0                 0                 0                1
# 1318                 0                 0                 0                1
# 873                  0                 0                 0                1
# 925                  0                 0                 0                1
# 2215                 0                 0                 0                1
#
#       RoofStyle_Gambrel  RoofStyle_Hip  RoofStyle_Mansard  RoofStyle_Shed  \
# Id
# 274                   0              1                  0               0
# 1645                  0              0                  0               0
# 1318                  0              0                  0               0
# 873                   0              0                  0               0
# 925                   0              0                  0               0
# 2215                  0              0                  0               0
#
#       SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# Id
# 274                       0                     0                     0
# 1645                      0                     0                     0
# 1318                      0                     0                     0
# 873                       0                     0                     0
# 925                       0                     0                     0
# 2215                      0                     0                     0
#
#       SaleCondition_Normal  SaleCondition_Partial  SaleType_CWD  SaleType_Con  \
# Id
# 274                      1                      0             0             0
# 1645                     1                      0             0             0
# 1318                     0                      1             0             0
# 873                      1                      0             0             0
# 925                      1                      0             0             0
# 2215                     1                      0             0             0
#
#       SaleType_ConLD  SaleType_ConLI  SaleType_ConLw  SaleType_New  \
# Id
# 274                0               0               0             0
# 1645               0               0               0             0
# 1318               0               0               0             1
# 873                0               0               0             0
# 925                0               0               0             0
# 2215               0               0               0             0
#
#       SaleType_Oth  SaleType_WD  Street_Pave  Utilities_NoSeWa  Utilities_None
# Id
# 274              0            1            1                 0               0
# 1645             0            1            1                 0               0
# 1318             0            0            1                 0               0
# 873              0            1            1                 0               0
# 925              0            1            1                 0               0
# 2215             0            1            1                 0               0

# %%
combine.shape
# Out:
# (2919, 261)

# %% [markdown]
# # Split dataframe

# %%
train = combine[combine.SalePrice!=0]
test = combine[combine.SalePrice==0]

# %%
print(train.shape)
print(test.shape)
# Out:
# (1460, 261)
# (1459, 261)

# %%
test.columns.tolist()
# Out:
# ['1stFlrSF',
#  '2ndFlrSF',
#  '3SsnPorch',
#  'BedroomAbvGr',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'BsmtUnfSF',
#  'EnclosedPorch',
#  'Fireplaces',
#  'FullBath',
#  'GarageArea',
#  'GarageCars',
#  'GarageYrBlt',
#  'GrLivArea',
#  'HalfBath',
#  'KitchenAbvGr',
#  'LotArea',
#  'LotFrontage',
#  'LowQualFinSF',
#  'MSSubClass',
#  'MasVnrArea',
#  'MiscVal',
#  'MoSold',
#  'OpenPorchSF',
#  'OverallCond',
#  'OverallQual',
#  'PoolArea',
#  'SalePrice',
#  'ScreenPorch',
#  'TotRmsAbvGrd',
#  'TotalBsmtSF',
#  'WoodDeckSF',
#  'YearBuilt',
#  'YearRemodAdd',
#  'YrSold',
#  'Alley_None',
#  'Alley_Pave',
#  'BldgType_2fmCon',
#  'BldgType_Duplex',
#  'BldgType_Twnhs',
#  'BldgType_TwnhsE',
#  'BsmtCond_Gd',
#  'BsmtCond_None',
#  'BsmtCond_Po',
#  'BsmtCond_TA',
#  'BsmtExposure_Gd',
#  'BsmtExposure_Mn',
#  'BsmtExposure_No',
#  'BsmtExposure_None',
#  'BsmtFinType1_BLQ',
#  'BsmtFinType1_GLQ',
#  'BsmtFinType1_LwQ',
#  'BsmtFinType1_None',
#  'BsmtFinType1_Rec',
#  'BsmtFinType1_Unf',
#  'BsmtFinType2_BLQ',
#  'BsmtFinType2_GLQ',
#  'BsmtFinType2_LwQ',
#  'BsmtFinType2_None',
#  'BsmtFinType2_Rec',
#  'BsmtFinType2_Unf',
#  'BsmtQual_Fa',
#  'BsmtQual_Gd',
#  'BsmtQual_None',
#  'BsmtQual_TA',
#  'CentralAir_Y',
#  'Condition1_Feedr',
#  'Condition1_Norm',
#  'Condition1_PosA',
#  'Condition1_PosN',
#  'Condition1_RRAe',
#  'Condition1_RRAn',
#  'Condition1_RRNe',
#  'Condition1_RRNn',
#  'Condition2_Feedr',
#  'Condition2_Norm',
#  'Condition2_PosA',
#  'Condition2_PosN',
#  'Condition2_RRAe',
#  'Condition2_RRAn',
#  'Condition2_RRNn',
#  'Electrical_FuseF',
#  'Electrical_FuseP',
#  'Electrical_Mix',
#  'Electrical_SBrkr',
#  'ExterCond_Fa',
#  'ExterCond_Gd',
#  'ExterCond_Po',
#  'ExterCond_TA',
#  'ExterQual_Fa',
#  'ExterQual_Gd',
#  'ExterQual_TA',
#  'Exterior1st_AsphShn',
#  'Exterior1st_BrkComm',
#  'Exterior1st_BrkFace',
#  'Exterior1st_CBlock',
#  'Exterior1st_CemntBd',
#  'Exterior1st_HdBoard',
#  'Exterior1st_ImStucc',
#  'Exterior1st_MetalSd',
#  'Exterior1st_Plywood',
#  'Exterior1st_Stone',
#  'Exterior1st_Stucco',
#  'Exterior1st_VinylSd',
#  'Exterior1st_Wd Sdng',
#  'Exterior1st_WdShing',
#  'Exterior2nd_AsphShn',
#  'Exterior2nd_Brk Cmn',
#  'Exterior2nd_BrkFace',
#  'Exterior2nd_CBlock',
#  'Exterior2nd_CmentBd',
#  'Exterior2nd_HdBoard',
#  'Exterior2nd_ImStucc',
#  'Exterior2nd_MetalSd',
#  'Exterior2nd_Other',
#  'Exterior2nd_Plywood',
#  'Exterior2nd_Stone',
#  'Exterior2nd_Stucco',
#  'Exterior2nd_VinylSd',
#  'Exterior2nd_Wd Sdng',
#  'Exterior2nd_Wd Shng',
#  'Fence_GdWo',
#  'Fence_MnPrv',
#  'Fence_MnWw',
#  'Fence_None',
#  'FireplaceQu_Fa',
#  'FireplaceQu_Gd',
#  'FireplaceQu_None',
#  'FireplaceQu_Po',
#  'FireplaceQu_TA',
#  'Foundation_CBlock',
#  'Foundation_PConc',
#  'Foundation_Slab',
#  'Foundation_Stone',
#  'Foundation_Wood',
#  'Functional_Maj2',
#  'Functional_Min1',
#  'Functional_Min2',
#  'Functional_Mod',
#  'Functional_Sev',
#  'Functional_Typ',
#  'GarageCond_Fa',
#  'GarageCond_Gd',
#  'GarageCond_None',
#  'GarageCond_Po',
#  'GarageCond_TA',
#  'GarageFinish_None',
#  'GarageFinish_RFn',
#  'GarageFinish_Unf',
#  'GarageQual_Fa',
#  'GarageQual_Gd',
#  'GarageQual_None',
#  'GarageQual_Po',
#  'GarageQual_TA',
#  'GarageType_Attchd',
#  'GarageType_Basment',
#  'GarageType_BuiltIn',
#  'GarageType_CarPort',
#  'GarageType_Detchd',
#  'GarageType_None',
#  'Heating_GasA',
#  'Heating_GasW',
#  'Heating_Grav',
#  'Heating_OthW',
#  'Heating_Wall',
#  'HeatingQC_Fa',
#  'HeatingQC_Gd',
#  'HeatingQC_Po',
#  'HeatingQC_TA',
#  'HouseStyle_1.5Unf',
#  'HouseStyle_1Story',
#  'HouseStyle_2.5Fin',
#  'HouseStyle_2.5Unf',
#  'HouseStyle_2Story',
#  'HouseStyle_SFoyer',
#  'HouseStyle_SLvl',
#  'KitchenQual_Fa',
#  'KitchenQual_Gd',
#  'KitchenQual_TA',
#  'LandContour_HLS',
#  'LandContour_Low',
#  'LandContour_Lvl',
#  'LandSlope_Mod',
#  'LandSlope_Sev',
#  'LotConfig_CulDSac',
#  'LotConfig_FR2',
#  'LotConfig_FR3',
#  'LotConfig_Inside',
#  'LotShape_IR2',
#  'LotShape_IR3',
#  'LotShape_Reg',
#  'MSZoning_FV',
#  'MSZoning_RH',
#  'MSZoning_RL',
#  'MSZoning_RM',
#  'MasVnrType_BrkFace',
#  'MasVnrType_None',
#  'MasVnrType_Stone',
#  'MiscFeature_None',
#  'MiscFeature_Othr',
#  'MiscFeature_Shed',
#  'MiscFeature_TenC',
#  'Neighborhood_Blueste',
#  'Neighborhood_BrDale',
#  'Neighborhood_BrkSide',
#  'Neighborhood_ClearCr',
#  'Neighborhood_CollgCr',
#  'Neighborhood_Crawfor',
#  'Neighborhood_Edwards',
#  'Neighborhood_Gilbert',
#  'Neighborhood_IDOTRR',
#  'Neighborhood_MeadowV',
#  'Neighborhood_Mitchel',
#  'Neighborhood_NAmes',
#  'Neighborhood_NPkVill',
#  'Neighborhood_NWAmes',
#  'Neighborhood_NoRidge',
#  'Neighborhood_NridgHt',
#  'Neighborhood_OldTown',
#  'Neighborhood_SWISU',
#  'Neighborhood_Sawyer',
#  'Neighborhood_SawyerW',
#  'Neighborhood_Somerst',
#  'Neighborhood_StoneBr',
#  'Neighborhood_Timber',
#  'Neighborhood_Veenker',
#  'PavedDrive_P',
#  'PavedDrive_Y',
#  'PoolQC_Fa',
#  'PoolQC_Gd',
#  'PoolQC_None',
#  'RoofMatl_CompShg',
#  'RoofMatl_Membran',
#  'RoofMatl_Metal',
#  'RoofMatl_Roll',
#  'RoofMatl_Tar&Grv',
#  'RoofMatl_WdShake',
#  'RoofMatl_WdShngl',
#  'RoofStyle_Gable',
#  'RoofStyle_Gambrel',
#  'RoofStyle_Hip',
#  'RoofStyle_Mansard',
#  'RoofStyle_Shed',
#  'SaleCondition_AdjLand',
#  'SaleCondition_Alloca',
#  'SaleCondition_Family',
#  'SaleCondition_Normal',
#  'SaleCondition_Partial',
#  'SaleType_CWD',
#  'SaleType_Con',
#  'SaleType_ConLD',
#  'SaleType_ConLI',
#  'SaleType_ConLw',
#  'SaleType_New',
#  'SaleType_Oth',
#  'SaleType_WD',
#  'Street_Pave',
#  'Utilities_NoSeWa',
#  'Utilities_None']

# %% [markdown]
# # Outliers

# %% [markdown]
# Defining function to plot Target against every input variable

# %%
numeric_cols = train_df.select_dtypes(['number']).columns
numeric_cols
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
# creating a dataframe of continous variables

cont_df = train[ num_features]

# %%
def find_outliers(feature, target):
    fig, ax = plt.subplots()
    ax.scatter(x = feature, y = target)
    plt.ylabel('SalePrice', fontsize=13)
    plt.xlabel(feature.name, fontsize=13)
    plt.show()

# %%
i=0
for i in range(len(cont_df.columns)-1):
    find_outliers(cont_df.iloc[:,i], cont_df.SalePrice)

# %%
cont_df.corr()
# Out:
#                1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1
# FullBath          0.323722    0.187703   0.468271      0.439046 -0.019669
# GarageArea        0.486665    0.224666   0.478954      0.371600 -0.027378
# GarageCars        0.434585    0.226342   0.537850      0.420622 -0.039117
# GarageYrBlt       0.343539    0.238464   0.754433      0.554339 -0.007688
# GrLivArea         0.454868    0.247433   0.199010      0.287389 -0.036526
# HalfBath         -0.048804    0.108080   0.242656      0.183331 -0.010269
# KitchenAbvGr     -0.068901   -0.090130  -0.174800     -0.149598  0.031687
# LotArea           0.260833    0.171698   0.014228      0.013788 -0.014261
# LotFrontage       0.381556    0.089164   0.120993      0.084645  0.004255
# LowQualFinSF     -0.033245   -0.025444  -0.183784     -0.062419 -0.028921
# MasVnrArea        0.360067    0.159991   0.311600      0.176529 -0.008317
# MiscVal          -0.018479   -0.009551  -0.034383     -0.010286  0.004906
# MoSold            0.013196    0.021011   0.012398      0.021490 -0.145721
# OpenPorchSF       0.247264    0.058661   0.188686      0.226298 -0.057619
# PoolArea          0.126053    0.073378   0.004950      0.005829 -0.059689
# SalePrice         0.613581    0.324413   0.522897      0.507101 -0.028923
# ScreenPorch       0.084489   -0.074181  -0.050364     -0.038740  0.010694
# TotRmsAbvGrd      0.285573    0.165984   0.095589      0.191740 -0.034516
# TotalBsmtSF       1.000000    0.232019   0.391452      0.291066 -0.014969
# WoodDeckSF        0.232019    1.000000   0.224880      0.205726  0.022270
# YearBuilt         0.391452    0.224880   1.000000      0.592855 -0.013618
# YearRemodAdd      0.291066    0.205726   0.592855      1.000000  0.035743
# YrSold           -0.014969    0.022270  -0.013618      0.035743  1.000000

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

corr = cont_df.corr()

# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio

sns.heatmap(corr, mask=mask, cmap=cmap, vmax= 1, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# Sale Price is strongly correlated with these continous variable, so we will eliminate outliers from these
#
# Predictor : Correlation with Price
# ------------------------------------------------
#
# GrLivArea :    0.708624
#
# GarageCars : 0.640409
#
# GarageArea:   0.623431
#
# TotalBsmtSF : 0.613581
#
# 1stFlrSF  :  0.605852
#
# TotRmsAbvGrd :   0.533723
#
# FullBath  :  0.560664

# %% [markdown]
# Following are the two outliers which might effect out prediction

# %%
train[(train['GrLivArea']>4000) & (train['SalePrice']<300000)]
# Out:
#       1stFlrSF  2ndFlrSF  3SsnPorch  BedroomAbvGr  BsmtFinSF1  BsmtFinSF2  \
# Id
# 524       3138      1538          0             3      2260.0         0.0
# 1299      4692       950          0             3      5644.0         0.0
#
#       BsmtFullBath  BsmtHalfBath  BsmtUnfSF  EnclosedPorch  Fireplaces  \
# Id
# 524            1.0           0.0      878.0              0           1
# 1299           2.0           0.0      466.0              0           3
#
#       FullBath  GarageArea  GarageCars  GarageYrBlt  GrLivArea  HalfBath  \
# Id
# 524          3       884.0         3.0       2007.0       4676         1
# 1299         2      1418.0         2.0       2008.0       5642         1
#
#       KitchenAbvGr  LotArea  LotFrontage  LowQualFinSF  MSSubClass  \
# Id
# 524              1    40094        130.0             0          60
# 1299             1    63887        313.0             0          60
#
#       MasVnrArea  MiscVal  MoSold  OpenPorchSF  OverallCond  OverallQual  \
# Id
# 524        762.0        0      10          406            5           10
# 1299       796.0        0       1          292            5           10
#
#       PoolArea  SalePrice  ScreenPorch  TotRmsAbvGrd  TotalBsmtSF  WoodDeckSF  \
# Id
# 524          0   184750.0            0            11       3138.0         208
# 1299       480   160000.0            0            12       6110.0         214
#
#       YearBuilt  YearRemodAdd  YrSold  Alley_None  Alley_Pave  \
# Id
# 524        2007          2008    2007           1           0
# 1299       2008          2008    2008           1           0
#
#       BldgType_2fmCon  BldgType_Duplex  BldgType_Twnhs  BldgType_TwnhsE  \
# Id
# 524                 0                0               0                0
# 1299                0                0               0                0
#
#       BsmtCond_Gd  BsmtCond_None  BsmtCond_Po  BsmtCond_TA  BsmtExposure_Gd  \
# Id
# 524             0              0            0            1                1
# 1299            0              0            0            1                1
#
#       BsmtExposure_Mn  BsmtExposure_No  BsmtExposure_None  BsmtFinType1_BLQ  \
# Id
# 524                 0                0                  0                 0
# 1299                0                0                  0                 0
#
#       BsmtFinType1_GLQ  BsmtFinType1_LwQ  BsmtFinType1_None  BsmtFinType1_Rec  \
# Id
# 524                  1                 0                  0                 0
# 1299                 1                 0                  0                 0
#
#       BsmtFinType1_Unf  BsmtFinType2_BLQ  BsmtFinType2_GLQ  BsmtFinType2_LwQ  \
# Id
# 524                  0                 0                 0                 0
# 1299                 0                 0                 0                 0
#
#       BsmtFinType2_None  BsmtFinType2_Rec  BsmtFinType2_Unf  BsmtQual_Fa  \
# Id
# 524                   0                 0                 1            0
# 1299                  0                 0                 1            0
#
#       BsmtQual_Gd  BsmtQual_None  BsmtQual_TA  CentralAir_Y  Condition1_Feedr  \
# Id
# 524             0              0            0             1                 0
# 1299            0              0            0             1                 1
#
#       Condition1_Norm  Condition1_PosA  Condition1_PosN  Condition1_RRAe  \
# Id
# 524                 0                0                1                0
# 1299                0                0                0                0
#
#       Condition1_RRAn  Condition1_RRNe  Condition1_RRNn  Condition2_Feedr  \
# Id
# 524                 0                0                0                 0
# 1299                0                0                0                 0
#
#       Condition2_Norm  Condition2_PosA  Condition2_PosN  Condition2_RRAe  \
# Id
# 524                 0                0                1                0
# 1299                1                0                0                0
#
#       Condition2_RRAn  Condition2_RRNn  Electrical_FuseF  Electrical_FuseP  \
# Id
# 524                 0                0                 0                 0
# 1299                0                0                 0                 0
#
#       Electrical_Mix  Electrical_SBrkr  ExterCond_Fa  ExterCond_Gd  \
# Id
# 524                0                 1             0             0
# 1299               0                 1             0             0
#
#       ExterCond_Po  ExterCond_TA  ExterQual_Fa  ExterQual_Gd  ExterQual_TA  \
# Id
# 524              0             1             0             0             0
# 1299             0             1             0             0             0
#
#       Exterior1st_AsphShn  Exterior1st_BrkComm  Exterior1st_BrkFace  \
# Id
# 524                     0                    0                    0
# 1299                    0                    0                    0
#
#       Exterior1st_CBlock  Exterior1st_CemntBd  Exterior1st_HdBoard  \
# Id
# 524                    0                    1                    0
# 1299                   0                    0                    0
#
#       Exterior1st_ImStucc  Exterior1st_MetalSd  Exterior1st_Plywood  \
# Id
# 524                     0                    0                    0
# 1299                    0                    0                    0
#
#       Exterior1st_Stone  Exterior1st_Stucco  Exterior1st_VinylSd  \
# Id
# 524                   0                   0                    0
# 1299                  0                   1                    0
#
#       Exterior1st_Wd Sdng  Exterior1st_WdShing  Exterior2nd_AsphShn  \
# Id
# 524                     0                    0                    0
# 1299                    0                    0                    0
#
#       Exterior2nd_Brk Cmn  Exterior2nd_BrkFace  Exterior2nd_CBlock  \
# Id
# 524                     0                    0                   0
# 1299                    0                    0                   0
#
#       Exterior2nd_CmentBd  Exterior2nd_HdBoard  Exterior2nd_ImStucc  \
# Id
# 524                     1                    0                    0
# 1299                    0                    0                    0
#
#       Exterior2nd_MetalSd  Exterior2nd_Other  Exterior2nd_Plywood  \
# Id
# 524                     0                  0                    0
# 1299                    0                  0                    0
#
#       Exterior2nd_Stone  Exterior2nd_Stucco  Exterior2nd_VinylSd  \
# Id
# 524                   0                   0                    0
# 1299                  0                   1                    0
#
#       Exterior2nd_Wd Sdng  Exterior2nd_Wd Shng  Fence_GdWo  Fence_MnPrv  \
# Id
# 524                     0                    0           0            0
# 1299                    0                    0           0            0
#
#       Fence_MnWw  Fence_None  FireplaceQu_Fa  FireplaceQu_Gd  \
# Id
# 524            0           1               0               1
# 1299           0           1               0               1
#
#       FireplaceQu_None  FireplaceQu_Po  FireplaceQu_TA  Foundation_CBlock  \
# Id
# 524                  0               0               0                  0
# 1299                 0               0               0                  0
#
#       Foundation_PConc  Foundation_Slab  Foundation_Stone  Foundation_Wood  \
# Id
# 524                  1                0                 0                0
# 1299                 1                0                 0                0
#
#       Functional_Maj2  Functional_Min1  Functional_Min2  Functional_Mod  \
# Id
# 524                 0                0                0               0
# 1299                0                0                0               0
#
#       Functional_Sev  Functional_Typ  GarageCond_Fa  GarageCond_Gd  \
# Id
# 524                0               1              0              0
# 1299               0               1              0              0
#
#       GarageCond_None  GarageCond_Po  GarageCond_TA  GarageFinish_None  \
# Id
# 524                 0              0              1                  0
# 1299                0              0              1                  0
#
#       GarageFinish_RFn  GarageFinish_Unf  GarageQual_Fa  GarageQual_Gd  \
# Id
# 524                  0                 0              0              0
# 1299                 0                 0              0              0
#
#       GarageQual_None  GarageQual_Po  GarageQual_TA  GarageType_Attchd  \
# Id
# 524                 0              0              1                  0
# 1299                0              0              1                  1
#
#       GarageType_Basment  GarageType_BuiltIn  GarageType_CarPort  \
# Id
# 524                    0                   1                   0
# 1299                   0                   0                   0
#
#       GarageType_Detchd  GarageType_None  Heating_GasA  Heating_GasW  \
# Id
# 524                   0                0             1             0
# 1299                  0                0             1             0
#
#       Heating_Grav  Heating_OthW  Heating_Wall  HeatingQC_Fa  HeatingQC_Gd  \
# Id
# 524              0             0             0             0             0
# 1299             0             0             0             0             0
#
#       HeatingQC_Po  HeatingQC_TA  HouseStyle_1.5Unf  HouseStyle_1Story  \
# Id
# 524              0             0                  0                  0
# 1299             0             0                  0                  0
#
#       HouseStyle_2.5Fin  HouseStyle_2.5Unf  HouseStyle_2Story  \
# Id
# 524                   0                  0                  1
# 1299                  0                  0                  1
#
#       HouseStyle_SFoyer  HouseStyle_SLvl  KitchenQual_Fa  KitchenQual_Gd  \
# Id
# 524                   0                0               0               0
# 1299                  0                0               0               0
#
#       KitchenQual_TA  LandContour_HLS  LandContour_Low  LandContour_Lvl  \
# Id
# 524                0                0                0                0
# 1299               0                0                0                0
#
#       LandSlope_Mod  LandSlope_Sev  LotConfig_CulDSac  LotConfig_FR2  \
# Id
# 524               0              0                  0              0
# 1299              0              0                  0              0
#
#       LotConfig_FR3  LotConfig_Inside  LotShape_IR2  LotShape_IR3  \
# Id
# 524               0                 1             0             0
# 1299              0                 0             0             1
#
#       LotShape_Reg  MSZoning_FV  MSZoning_RH  MSZoning_RL  MSZoning_RM  \
# Id
# 524              0            0            0            1            0
# 1299             0            0            0            1            0
#
#       MasVnrType_BrkFace  MasVnrType_None  MasVnrType_Stone  MiscFeature_None  \
# Id
# 524                    0                0                 1                 1
# 1299                   0                0                 1                 1
#
#       MiscFeature_Othr  MiscFeature_Shed  MiscFeature_TenC  \
# Id
# 524                  0                 0                 0
# 1299                 0                 0                 0
#
#       Neighborhood_Blueste  Neighborhood_BrDale  Neighborhood_BrkSide  \
# Id
# 524                      0                    0                     0
# 1299                     0                    0                     0
#
#       Neighborhood_ClearCr  Neighborhood_CollgCr  Neighborhood_Crawfor  \
# Id
# 524                      0                     0                     0
# 1299                     0                     0                     0
#
#       Neighborhood_Edwards  Neighborhood_Gilbert  Neighborhood_IDOTRR  \
# Id
# 524                      1                     0                    0
# 1299                     1                     0                    0
#
#       Neighborhood_MeadowV  Neighborhood_Mitchel  Neighborhood_NAmes  \
# Id
# 524                      0                     0                   0
# 1299                     0                     0                   0
#
#       Neighborhood_NPkVill  Neighborhood_NWAmes  Neighborhood_NoRidge  \
# Id
# 524                      0                    0                     0
# 1299                     0                    0                     0
#
#       Neighborhood_NridgHt  Neighborhood_OldTown  Neighborhood_SWISU  \
# Id
# 524                      0                     0                   0
# 1299                     0                     0                   0
#
#       Neighborhood_Sawyer  Neighborhood_SawyerW  Neighborhood_Somerst  \
# Id
# 524                     0                     0                     0
# 1299                    0                     0                     0
#
#       Neighborhood_StoneBr  Neighborhood_Timber  Neighborhood_Veenker  \
# Id
# 524                      0                    0                     0
# 1299                     0                    0                     0
#
#       PavedDrive_P  PavedDrive_Y  PoolQC_Fa  PoolQC_Gd  PoolQC_None  \
# Id
# 524              0             1          0          0            1
# 1299             0             1          0          1            0
#
#       RoofMatl_CompShg  RoofMatl_Membran  RoofMatl_Metal  RoofMatl_Roll  \
# Id
# 524                  1                 0               0              0
# 1299                 0                 0               0              0
#
#       RoofMatl_Tar&Grv  RoofMatl_WdShake  RoofMatl_WdShngl  RoofStyle_Gable  \
# Id
# 524                  0                 0                 0                0
# 1299                 0                 0                 0                0
#
#       RoofStyle_Gambrel  RoofStyle_Hip  RoofStyle_Mansard  RoofStyle_Shed  \
# Id
# 524                   0              1                  0               0
# 1299                  0              1                  0               0
#
#       SaleCondition_AdjLand  SaleCondition_Alloca  SaleCondition_Family  \
# Id
# 524                       0                     0                     0
# 1299                      0                     0                     0
#
#       SaleCondition_Normal  SaleCondition_Partial  SaleType_CWD  SaleType_Con  \
# Id
# 524                      0                      1             0             0
# 1299                     0                      1             0             0
#
#       SaleType_ConLD  SaleType_ConLI  SaleType_ConLw  SaleType_New  \
# Id
# 524                0               0               0             1
# 1299               0               0               0             1
#
#       SaleType_Oth  SaleType_WD  Street_Pave  Utilities_NoSeWa  Utilities_None
# Id
# 524              0            0            1                 0               0
# 1299             0            0            1                 0               0

# %% [markdown]
# Dropping the outliers brought in by variable GrLivArea

# %%
train = train.drop(train[(train.GrLivArea>4000) & (train.SalePrice<300000)].index)

train.shape
# Out:
# (1458, 261)

# %% [markdown]
# Checking the plots after dropping the outlier

# %%
cont_df = train_df[[ 'LotFrontage', 'LotArea',  'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
                  'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
                  'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
                   'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
                   'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
                   'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
                   'MoSold', 'SalePrice']]

find_outliers(cont_df.GrLivArea, cont_df.SalePrice)
find_outliers(cont_df.GarageCars, cont_df.SalePrice)
find_outliers(cont_df.GarageArea, cont_df.SalePrice)
find_outliers(cont_df.TotalBsmtSF, cont_df.SalePrice)
find_outliers(cont_df['1stFlrSF'], cont_df.SalePrice)
find_outliers(cont_df.TotRmsAbvGrd, cont_df.SalePrice)
find_outliers(cont_df.FullBath, cont_df.SalePrice)

# %% [markdown]
# Following observation shows outlier brought in by Garage Area, its detached garage where GrLivArea is only 894 , year built = 1935 for which such a low sale Price $81000 makes sense, so we are not dropping this outlier

# %%
train[(train.GarageArea>1200) & (train.SalePrice<100000)]
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1062          30  C (all)        120.0    18000   Grvl   NaN      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1062         Low    AllPub    Inside       Gtl       IDOTRR       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1062       Norm     1Fam     1Story            3            4       1935
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1062          1950     Gable  CompShg     MetalSd     MetalSd       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1062         0.0        Fa        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1062           No          Unf           0          Unf           0
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1062        894          894    GasA        TA          Y      SBrkr
#
#       1stFlrSF  2ndFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  \
# Id
# 1062       894         0             0        894             0             0
#
#       FullBath  HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  \
# Id
# 1062         1         0             2             1          TA
#
#       TotRmsAbvGrd Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt  \
# Id
# 1062             6        Typ           0         NaN     Detchd       1994.0
#
#      GarageFinish  GarageCars  GarageArea GarageQual GarageCond PavedDrive  \
# Id
# 1062          RFn           3        1248         TA         TA          Y
#
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# Id
# 1062           0           20              0          0            0
#
#       PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# Id
# 1062         0    NaN   NaN        Shed      560       8    2008    ConLD
#
#      SaleCondition  SalePrice
# Id
# 1062        Normal      81000

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# # Analysis of Target variable

# %% [markdown]
# We want to predict SalePrice. Let's check the distribution of target variable

# %%
plt.figure(figsize = (8,6))

sns.distplot(train.SalePrice, bins=50, fit= stats.norm);

# Get the fitted parameters used by the function
(mean, sd) = stats.norm.fit(train.SalePrice)
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mean, sd))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mean, sd)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Distribution of Sale Price')
# Out:
#  mu = 180932.92 and sigma = 79467.79
# Text(0.5, 1.0, 'Distribution of Sale Price')

# %%
# Q Q plot
plt.figure(figsize = (8,6))
stats.probplot(train.SalePrice, plot=plt)
plt.show()

# %% [markdown]
# The Sale price follows normal distribution but has a right skew. As the Q Q plot shows, its following the law of linearity but needs improvement. Let's check what it looks like after transformation

# %% [markdown]
# # Transformation of target variable

# %%
train.SalePrice = np.log(train.SalePrice)

plt.figure(figsize = (8,6))

sns.distplot(train.SalePrice, bins=50, fit= stats.norm);

# Get the fitted parameters used by the function
(mean, sd) = stats.norm.fit(train.SalePrice)
print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mean, sd))

#Now plot the distribution
plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mean, sd)],
            loc='best')
plt.ylabel('Frequency')
plt.title('Distribution of Sale Price')
# Out:
#  mu = 12.02 and sigma = 0.40
# Text(0.5, 1.0, 'Distribution of Sale Price')

# %%
# Q Q plot
plt.figure(figsize = (8,6))
stats.probplot(train.SalePrice, plot=plt)
plt.show()

# %% [markdown]
# As the plots shows log transforming the price gives better results, we will transform it back after prediction using np.exp

# %% [markdown]
# # Check for skewness in predictors

# %%
# run to check which variable needs transformation
train_df[[ 'LotFrontage', 'LotArea',  'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
                  'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', 
          #'2ndFlrSF', 
          'LowQualFinSF',
                  'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
                   'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
                   'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
                   'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
                   'MoSold', 'SalePrice']].hist(bins = 50, figsize = (20,24))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002217693DE10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002217526D320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221763BFB70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221769BF2E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022176E36BE0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022176E45198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022176E4E710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022176E58CC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022176E58CF8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022176E807B8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022176E9FD30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022176EC52E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022176EE8860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022176F08DD8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022176F31390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x0000022176F58908>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022176F80E80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022176FAE438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022176FD79B0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022176FFFF28>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000002217702E4E0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022177056A58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002217707EFD0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221770AE588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221770D5B00>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000221771060B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000002217712D630>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022177155BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000022177186160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000221771AE6D8>]],
#       dtype=object)

# %% [markdown]
# Transform 1stFlSF and 2ndFlSF into 1 column and add no_of_fl column as 1/2 as identifier

# %%
# run following line once it adds second floor SF to first FL sq rerunning will add it again
# train_df['1stFlrSF'] = train_df['1stFlrSF'] + train_df['2ndFlrSF'] 
# train_df.head(3)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave  None      Reg
# 2           20       RL         80.0     9600   Pave  None      Reg
# 3           60       RL         68.0    11250   Pave  None      IR1
#
#    LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# 2          Lvl    AllPub       FR2       Gtl      Veenker      Feedr
# 3          Lvl    AllPub    Inside       Gtl      CollgCr       Norm
#
#    Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1        Norm     1Fam     2Story            7            5       2003
# 2        Norm     1Fam     1Story            6            8       1976
# 3        Norm     1Fam     2Story            7            5       2001
#
#     YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1           2003     Gable  CompShg     VinylSd     VinylSd    BrkFace
# 2           1976     Gable  CompShg     MetalSd     MetalSd       None
# 3           2002     Gable  CompShg     VinylSd     VinylSd    BrkFace
#
#     MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond BsmtExposure  \
# Id
# 1        196.0        Gd        TA      PConc       Gd       TA           No
# 2          0.0        TA        TA     CBlock       Gd       TA           Gd
# 3        162.0        Gd        TA      PConc       Gd       TA           Mn
#
#    BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  \
# Id
# 1           GLQ         706          Unf           0        150          856
# 2           ALQ         978          Unf           0        284         1262
# 3           GLQ         486          Unf           0        434          920
#
#    Heating HeatingQC CentralAir Electrical  1stFlrSF  2ndFlrSF  LowQualFinSF  \
# Id
# 1     GasA        Ex          Y      SBrkr      1710       854             0
# 2     GasA        Ex          Y      SBrkr      1262         0             0
# 3     GasA        Ex          Y      SBrkr      1786       866             0
#
#     GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  HalfBath  BedroomAbvGr  \
# Id
# 1        1710             1             0         2         1             3
# 2        1262             0             1         2         0             3
# 3        1786             1             0         2         1             3
#
#     KitchenAbvGr KitchenQual  TotRmsAbvGrd Functional  Fireplaces FireplaceQu  \
# Id
# 1              1          Gd             8        Typ           0        None
# 2              1          TA             6        Typ           1          TA
# 3              1          Gd             6        Typ           1          TA
#
#    GarageType  GarageYrBlt GarageFinish  GarageCars  GarageArea GarageQual  \
# Id
# 1      Attchd       2003.0          RFn           2         548         TA
# 2      Attchd       1976.0          RFn           2         460         TA
# 3      Attchd       2001.0          RFn           2         608         TA
#
#    GarageCond PavedDrive  WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  \
# Id
# 1          TA          Y           0           61              0          0
# 2          TA          Y         298            0              0          0
# 3          TA          Y           0           42              0          0
#
#     ScreenPorch  PoolArea PoolQC Fence MiscFeature  MiscVal  MoSold  YrSold  \
# Id
# 1             0         0   None  None        None        0       2    2008
# 2             0         0   None  None        None        0       5    2007
# 3             0         0   None  None        None        0       9    2008
#
#    SaleType SaleCondition  SalePrice  no_of_fl
# Id
# 1        WD        Normal  12.247694         2
# 2        WD        Normal  12.109011         1
# 3        WD        Normal  12.317167         2

# %%
# dropping 2ndFlrSF because its already accounted in 1stFlr variable
# train_df = train_df.drop(['2ndFlrSF'], axis=1)

# %% [markdown]
#  ## Add the square foots

# %%
# Adding total sqfootage feature 
train['TotalSF'] = train['TotalBsmtSF'] + train['1stFlrSF'] + train['2ndFlrSF']
test['TotalSF'] = test['TotalBsmtSF'] + test['1stFlrSF'] + test['2ndFlrSF']

# %%
train.shape
# Out:
# (1458, 262)

# %%
test.shape
# Out:
# (1459, 262)

# %%
test.columns.tolist()
# Out:
# ['1stFlrSF',
#  '2ndFlrSF',
#  '3SsnPorch',
#  'BedroomAbvGr',
#  'BsmtFinSF1',
#  'BsmtFinSF2',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'BsmtUnfSF',
#  'EnclosedPorch',
#  'Fireplaces',
#  'FullBath',
#  'GarageArea',
#  'GarageCars',
#  'GarageYrBlt',
#  'GrLivArea',
#  'HalfBath',
#  'KitchenAbvGr',
#  'LotArea',
#  'LotFrontage',
#  'LowQualFinSF',
#  'MSSubClass',
#  'MasVnrArea',
#  'MiscVal',
#  'MoSold',
#  'OpenPorchSF',
#  'OverallCond',
#  'OverallQual',
#  'PoolArea',
#  'SalePrice',
#  'ScreenPorch',
#  'TotRmsAbvGrd',
#  'TotalBsmtSF',
#  'WoodDeckSF',
#  'YearBuilt',
#  'YearRemodAdd',
#  'YrSold',
#  'Alley_None',
#  'Alley_Pave',
#  'BldgType_2fmCon',
#  'BldgType_Duplex',
#  'BldgType_Twnhs',
#  'BldgType_TwnhsE',
#  'BsmtCond_Gd',
#  'BsmtCond_None',
#  'BsmtCond_Po',
#  'BsmtCond_TA',
#  'BsmtExposure_Gd',
#  'BsmtExposure_Mn',
#  'BsmtExposure_No',
#  'BsmtExposure_None',
#  'BsmtFinType1_BLQ',
#  'BsmtFinType1_GLQ',
#  'BsmtFinType1_LwQ',
#  'BsmtFinType1_None',
#  'BsmtFinType1_Rec',
#  'BsmtFinType1_Unf',
#  'BsmtFinType2_BLQ',
#  'BsmtFinType2_GLQ',
#  'BsmtFinType2_LwQ',
#  'BsmtFinType2_None',
#  'BsmtFinType2_Rec',
#  'BsmtFinType2_Unf',
#  'BsmtQual_Fa',
#  'BsmtQual_Gd',
#  'BsmtQual_None',
#  'BsmtQual_TA',
#  'CentralAir_Y',
#  'Condition1_Feedr',
#  'Condition1_Norm',
#  'Condition1_PosA',
#  'Condition1_PosN',
#  'Condition1_RRAe',
#  'Condition1_RRAn',
#  'Condition1_RRNe',
#  'Condition1_RRNn',
#  'Condition2_Feedr',
#  'Condition2_Norm',
#  'Condition2_PosA',
#  'Condition2_PosN',
#  'Condition2_RRAe',
#  'Condition2_RRAn',
#  'Condition2_RRNn',
#  'Electrical_FuseF',
#  'Electrical_FuseP',
#  'Electrical_Mix',
#  'Electrical_SBrkr',
#  'ExterCond_Fa',
#  'ExterCond_Gd',
#  'ExterCond_Po',
#  'ExterCond_TA',
#  'ExterQual_Fa',
#  'ExterQual_Gd',
#  'ExterQual_TA',
#  'Exterior1st_AsphShn',
#  'Exterior1st_BrkComm',
#  'Exterior1st_BrkFace',
#  'Exterior1st_CBlock',
#  'Exterior1st_CemntBd',
#  'Exterior1st_HdBoard',
#  'Exterior1st_ImStucc',
#  'Exterior1st_MetalSd',
#  'Exterior1st_Plywood',
#  'Exterior1st_Stone',
#  'Exterior1st_Stucco',
#  'Exterior1st_VinylSd',
#  'Exterior1st_Wd Sdng',
#  'Exterior1st_WdShing',
#  'Exterior2nd_AsphShn',
#  'Exterior2nd_Brk Cmn',
#  'Exterior2nd_BrkFace',
#  'Exterior2nd_CBlock',
#  'Exterior2nd_CmentBd',
#  'Exterior2nd_HdBoard',
#  'Exterior2nd_ImStucc',
#  'Exterior2nd_MetalSd',
#  'Exterior2nd_Other',
#  'Exterior2nd_Plywood',
#  'Exterior2nd_Stone',
#  'Exterior2nd_Stucco',
#  'Exterior2nd_VinylSd',
#  'Exterior2nd_Wd Sdng',
#  'Exterior2nd_Wd Shng',
#  'Fence_GdWo',
#  'Fence_MnPrv',
#  'Fence_MnWw',
#  'Fence_None',
#  'FireplaceQu_Fa',
#  'FireplaceQu_Gd',
#  'FireplaceQu_None',
#  'FireplaceQu_Po',
#  'FireplaceQu_TA',
#  'Foundation_CBlock',
#  'Foundation_PConc',
#  'Foundation_Slab',
#  'Foundation_Stone',
#  'Foundation_Wood',
#  'Functional_Maj2',
#  'Functional_Min1',
#  'Functional_Min2',
#  'Functional_Mod',
#  'Functional_Sev',
#  'Functional_Typ',
#  'GarageCond_Fa',
#  'GarageCond_Gd',
#  'GarageCond_None',
#  'GarageCond_Po',
#  'GarageCond_TA',
#  'GarageFinish_None',
#  'GarageFinish_RFn',
#  'GarageFinish_Unf',
#  'GarageQual_Fa',
#  'GarageQual_Gd',
#  'GarageQual_None',
#  'GarageQual_Po',
#  'GarageQual_TA',
#  'GarageType_Attchd',
#  'GarageType_Basment',
#  'GarageType_BuiltIn',
#  'GarageType_CarPort',
#  'GarageType_Detchd',
#  'GarageType_None',
#  'Heating_GasA',
#  'Heating_GasW',
#  'Heating_Grav',
#  'Heating_OthW',
#  'Heating_Wall',
#  'HeatingQC_Fa',
#  'HeatingQC_Gd',
#  'HeatingQC_Po',
#  'HeatingQC_TA',
#  'HouseStyle_1.5Unf',
#  'HouseStyle_1Story',
#  'HouseStyle_2.5Fin',
#  'HouseStyle_2.5Unf',
#  'HouseStyle_2Story',
#  'HouseStyle_SFoyer',
#  'HouseStyle_SLvl',
#  'KitchenQual_Fa',
#  'KitchenQual_Gd',
#  'KitchenQual_TA',
#  'LandContour_HLS',
#  'LandContour_Low',
#  'LandContour_Lvl',
#  'LandSlope_Mod',
#  'LandSlope_Sev',
#  'LotConfig_CulDSac',
#  'LotConfig_FR2',
#  'LotConfig_FR3',
#  'LotConfig_Inside',
#  'LotShape_IR2',
#  'LotShape_IR3',
#  'LotShape_Reg',
#  'MSZoning_FV',
#  'MSZoning_RH',
#  'MSZoning_RL',
#  'MSZoning_RM',
#  'MasVnrType_BrkFace',
#  'MasVnrType_None',
#  'MasVnrType_Stone',
#  'MiscFeature_None',
#  'MiscFeature_Othr',
#  'MiscFeature_Shed',
#  'MiscFeature_TenC',
#  'Neighborhood_Blueste',
#  'Neighborhood_BrDale',
#  'Neighborhood_BrkSide',
#  'Neighborhood_ClearCr',
#  'Neighborhood_CollgCr',
#  'Neighborhood_Crawfor',
#  'Neighborhood_Edwards',
#  'Neighborhood_Gilbert',
#  'Neighborhood_IDOTRR',
#  'Neighborhood_MeadowV',
#  'Neighborhood_Mitchel',
#  'Neighborhood_NAmes',
#  'Neighborhood_NPkVill',
#  'Neighborhood_NWAmes',
#  'Neighborhood_NoRidge',
#  'Neighborhood_NridgHt',
#  'Neighborhood_OldTown',
#  'Neighborhood_SWISU',
#  'Neighborhood_Sawyer',
#  'Neighborhood_SawyerW',
#  'Neighborhood_Somerst',
#  'Neighborhood_StoneBr',
#  'Neighborhood_Timber',
#  'Neighborhood_Veenker',
#  'PavedDrive_P',
#  'PavedDrive_Y',
#  'PoolQC_Fa',
#  'PoolQC_Gd',
#  'PoolQC_None',
#  'RoofMatl_CompShg',
#  'RoofMatl_Membran',
#  'RoofMatl_Metal',
#  'RoofMatl_Roll',
#  'RoofMatl_Tar&Grv',
#  'RoofMatl_WdShake',
#  'RoofMatl_WdShngl',
#  'RoofStyle_Gable',
#  'RoofStyle_Gambrel',
#  'RoofStyle_Hip',
#  'RoofStyle_Mansard',
#  'RoofStyle_Shed',
#  'SaleCondition_AdjLand',
#  'SaleCondition_Alloca',
#  'SaleCondition_Family',
#  'SaleCondition_Normal',
#  'SaleCondition_Partial',
#  'SaleType_CWD',
#  'SaleType_Con',
#  'SaleType_ConLD',
#  'SaleType_ConLI',
#  'SaleType_ConLw',
#  'SaleType_New',
#  'SaleType_Oth',
#  'SaleType_WD',
#  'Street_Pave',
#  'TotalSF']

# %% [markdown]
# 1. BsmtFinSF1 + BsmtFinSF2, gives the same information as TotalBsmtSF, so BsmtFinSF1 , BsmtFinSF2 its not adding any value , we can drop them
# 2. 'TotalBsmtSF','1stFlrSF','2ndFlrSF' can be dropped beacause we already added new feature 'TotalSF' which account for these
# 3. Utilities : For this categorical feature all records are "AllPub", except for one "NoSeWa" .This feature won't help in predictive modelling. We can then drop it.

# %%
# As learnt from this experiment droppig features is leading to worse predictions, we will kepp these features

# train.drop(columns = ['BsmtFinSF1','BsmtFinSF2', 'TotalBsmtSF','1stFlrSF','2ndFlrSF','Utilities_NoSeWa','Utilities_None'], inplace=True)
# test.drop(columns = ['BsmtFinSF1','BsmtFinSF2', 'TotalBsmtSF','1stFlrSF','2ndFlrSF','Utilities_NoSeWa','Utilities_None'], inplace=True)

# %%
train.drop(columns = ['Utilities_NoSeWa','Utilities_None'], inplace=True)

    
test.drop(columns = ['Utilities_NoSeWa','Utilities_None'], inplace=True)

# %%
print(train.shape)
test.shape
# Out:
# (1458, 260)
# (1459, 260)

# %% [markdown]
# # Modelling

# %%
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV

from sklearn.metrics import mean_squared_error

from sklearn.linear_model import Lasso, Ridge, ElasticNet, HuberRegressor
from sklearn.ensemble import RandomForestClassifier

from sklearn.pipeline import make_pipeline, Pipeline

from xgboost.sklearn import XGBRegressor

import xgboost as xgb

# %%
lasso = Lasso()
ridge = Ridge()
net = ElasticNet()
hub = HuberRegressor()
xgb_reg = XGBRegressor()

# %%
#split train data
X = train.drop('SalePrice', 1)
y = train.SalePrice

# %%
test = test.drop('SalePrice', 1)

# %% [markdown]
# ## XGBoost

# %%
parameters = {'nthread':[-1], #when use hyperthread, xgboost may become slower
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500],
              'alpha': list(np.linspace(1e-10,100,10)),
              'gamma': list(np.linspace(1e-10,100,10)),
              'lambda': list(np.linspace(1e-10,100,10))}

cv_xgb = GridSearchCV(xgb_reg,
                        parameters,
                        cv = 10,
                        n_jobs = 5,
                        verbose=True)

cv_xgb.fit(X,y)
print(cv_xgb.best_params_)
print(cv_xgb.best_score_)
# Out:
# Fitting 10 folds for each of 9000 candidates, totalling 90000 fits
# [Parallel(n_jobs=5)]: Using backend LokyBackend with 5 concurrent workers.
# [Parallel(n_jobs=5)]: Done  40 tasks      | elapsed:  1.0min
# [Parallel(n_jobs=5)]: Done 190 tasks      | elapsed:  4.7min
# [Parallel(n_jobs=5)]: Done 440 tasks      | elapsed: 11.1min
# [Parallel(n_jobs=5)]: Done 790 tasks      | elapsed: 19.8min
# [Parallel(n_jobs=5)]: Done 1240 tasks      | elapsed: 32.5min
# [Parallel(n_jobs=5)]: Done 1790 tasks      | elapsed: 52.1min
# [Parallel(n_jobs=5)]: Done 2440 tasks      | elapsed: 69.1min
# [Parallel(n_jobs=5)]: Done 3190 tasks      | elapsed: 91.2min
# [Parallel(n_jobs=5)]: Done 4040 tasks      | elapsed: 115.9min
# [Parallel(n_jobs=5)]: Done 4990 tasks      | elapsed: 155.0min
# [Parallel(n_jobs=5)]: Done 6040 tasks      | elapsed: 182.8min
# [Parallel(n_jobs=5)]: Done 7190 tasks      | elapsed: 212.7min
# [Parallel(n_jobs=5)]: Done 8440 tasks      | elapsed: 274.5min
# [Parallel(n_jobs=5)]: Done 9790 tasks      | elapsed: 307.0min
# [Parallel(n_jobs=5)]: Done 11240 tasks      | elapsed: 346.2min
# [Parallel(n_jobs=5)]: Done 12790 tasks      | elapsed: 765.5min
# [Parallel(n_jobs=5)]: Done 14440 tasks      | elapsed: 835.1min
# [Parallel(n_jobs=5)]: Done 16190 tasks      | elapsed: 910.7min
# [Parallel(n_jobs=5)]: Done 18040 tasks      | elapsed: 988.1min
# [Parallel(n_jobs=5)]: Done 19990 tasks      | elapsed: 1116.9min
# [Parallel(n_jobs=5)]: Done 22040 tasks      | elapsed: 1171.6min
# [Parallel(n_jobs=5)]: Done 24190 tasks      | elapsed: 1238.6min

# %%
cv_xgb.set_params()

# %%
xgb_grid.fit(x_train_full,
         y_train_full)

print(xgb_grid.best_score_)
print(xgb_grid.best_params_)

# %%
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

# %% [markdown]
# ## Ridge

# %%
#grid search

param_grid = [
  {'alpha': list(np.linspace(1e-10,100,10))}
 ]

cv_ridge = GridSearchCV(ridge, param_grid, cv=10, n_jobs=-1)
cv_ridge.fit(X,y)
print(cv_ridge.best_params_)
print(cv_ridge.best_score_)
# Out:
# {'alpha': 11.1111111112}
# 0.9174950126032989

# %%
ridge.set_params(alpha = 11.1111111112)
ridge.fit(X,y)
y_pred = np.exp(ridge.predict(test))
y_pred
# Out:
# array([114144.31880194, 152304.12130062, 180057.69655686, ...,
#        173456.10319588, 112751.08445323, 223675.78610926])

# %% [markdown]
# ## Lasso

# %%
#grid search

param_grid = [
  {'alpha': list(np.linspace(1e-10,100,10))}
 ]

cv_lasso = GridSearchCV(lasso, param_grid, cv=10, n_jobs=-1)
cv_lasso.fit(X,y)
print(cv_lasso.best_params_)
print(cv_lasso.best_score_)
# Out:
# {'alpha': 1e-10}
# 0.9080321827525965

# %%
lasso.set_params(alpha = 1e-10)
lasso.fit(X,y)
y_pred = np.exp(lasso.predict(test)) # this gives kaggle score of 0.14069,

# %%
# Out:
# (1458, 255)

# %% [markdown]
# ## Huber

# %%
#grid search

param_grid = [
  {'alpha': list(np.linspace(1e-10,100,10))}
 ]

cv_huber = GridSearchCV(hub, param_grid, cv=10, n_jobs=-1)
cv_huber.fit(X,y)
print(cv_huber.best_params_)
print(cv_huber.best_score_)
# Out:
# {'alpha': 11.1111111112}
# 0.8280678176363235

# %%
hub.set_params(alpha = 11.1111111112)
hub.fit(X,y)
y_pred = np.exp(hub.predict(test)) # this gives kaggle score of 0.14069,

# %% [markdown]
# ## Output

# %%
x = pd.concat([test.reset_index(), pd.Series(y_pred).rename('SalePrice')], axis=1)[['Id', 'SalePrice']].set_index('Id')
x.to_csv('price_ridge_may24.csv')

# %% [markdown]
# # Following steps are to plot log transformation to just use in slides

# %%
def check_skew(feature):
    plt.figure(figsize = (8,6))

    sns.distplot(train_df[feature], bins=50, fit= stats.norm)

    # Get the fitted parameters used by the function
    (mean, sd) = stats.norm.fit(train_df[feature])
    print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mean, sd))

    #Now plot the distribution
    plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mean, sd)],
                loc='best')
    plt.ylabel('Frequency')

# %%
for col in ('GrLivArea','LotArea','LotFrontage', '1stFlrSF'):
    check_skew(col)
# Out:
#  mu = 1510.47 and sigma = 507.70
#
#
#  mu = 10459.94 and sigma = 9855.82
#
#
#  mu = 69.99 and sigma = 21.46
#
#
#  mu = 1504.61 and sigma = 503.17

# %% [markdown]
# # Applying log transformation

# %%
def log_transform(feature):
    
    train_df[feature] = np.log(train_df[feature])
    
    plt.figure(figsize = (8,6))

    sns.distplot(train_df[feature], bins=50, fit= stats.norm)

    # Get the fitted parameters used by the function
    (mean, sd) = stats.norm.fit(train_df[feature])
    print( '\n mu = {:.2f} and sigma = {:.2f}\n'.format(mean, sd))

    #Now plot the distribution
    plt.legend(['Normal dist. ($\mu=$ {:.2f} and $\sigma=$ {:.2f} )'.format(mean, sd)],
                loc='best')
    plt.ylabel('Frequency')

# %%
for col in ('GrLivArea','LotArea','LotFrontage', '1stFlrSF'):
    log_transform(col)
# Out:
#  mu = 7.27 and sigma = 0.33
#
#
#  mu = 9.11 and sigma = 0.51
#
#
#  mu = 4.20 and sigma = 0.33
#
#
#  mu = 7.26 and sigma = 0.33

# %% [markdown]
# # log transform doesn't give much benefit, so we will revert it to original value

# %%
def revert_log(feature):
    train_df[feature] = np.exp(train_df[feature])
    
for col in ('GrLivArea','LotArea','LotFrontage', '1stFlrSF'):
    revert_log(col)

# %%
train_df.sample(6)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1016          60       RL         70.0   8400.0   Pave  None      Reg
# 1239          20       RL         63.0  13072.0   Pave  None      Reg
# 663           20       RL        120.0  13560.0   Pave  None      Reg
# 261           80       RL        120.0  19296.0   Pave  None      Reg
# 1011          50       RL        115.0  21286.0   Pave  None      Reg
# 855           20       RL        102.0  17920.0   Pave  None      Reg
#
#      LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# Id
# 1016         Lvl    AllPub    Inside       Gtl       NWAmes       Norm
# 1239         Lvl    AllPub    Inside       Gtl      SawyerW       RRAe
# 663          Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 261          Lvl    AllPub    Corner       Gtl        NAmes     Artery
# 1011         Lvl    AllPub    Inside       Gtl       Sawyer       Norm
# 855          Lvl    AllPub    Inside       Gtl       Sawyer       Norm
#
#      Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# Id
# 1016       Norm     1Fam     2Story            8            6       2001
# 1239       Norm     1Fam     1Story            6            5       2005
# 663        Norm     1Fam     1Story            6            3       1968
# 261        Norm     1Fam       SLvl            6            5       1962
# 1011       Norm     1Fam     1.5Fin            5            5       1948
# 855        Norm     1Fam     1Story            5            4       1955
#
#       YearRemodAdd RoofStyle RoofMatl Exterior1st Exterior2nd MasVnrType  \
# Id
# 1016          2001     Gable  CompShg     VinylSd     VinylSd       None
# 1239          2005     Gable  CompShg     VinylSd     VinylSd       None
# 663           1968       Hip  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 261           1962     Gable  CompShg     Wd Sdng     Wd Sdng    BrkFace
# 1011          1950     Gable  CompShg     Wd Sdng     Wd Sdng       None
# 855           1974       Hip  CompShg     Wd Sdng     Plywood       None
#
#       MasVnrArea ExterQual ExterCond Foundation BsmtQual BsmtCond  \
# Id
# 1016         0.0        Gd        TA      PConc       Gd       TA
# 1239         0.0        Gd        TA      PConc       Gd       TA
# 663        216.0        TA        TA     CBlock       Fa       Fa
# 261        399.0        TA        TA     CBlock       TA       TA
# 1011         0.0        TA        TA     CBlock       TA       TA
# 855          0.0        TA        TA     CBlock       TA       TA
#
#      BsmtExposure BsmtFinType1  BsmtFinSF1 BsmtFinType2  BsmtFinSF2  \
# Id
# 1016           No          GLQ         643          Unf           0
# 1239           No          Unf           0          Unf           0
# 663            No          Unf           0          Unf           0
# 261            Gd          Rec         672          ALQ         690
# 1011           No          Unf           0          Unf           0
# 855            Mn          ALQ         306          Rec        1085
#
#       BsmtUnfSF  TotalBsmtSF Heating HeatingQC CentralAir Electrical  \
# Id
# 1016        167          810    GasA        Ex          Y      SBrkr
# 1239       1141         1141    GasA        Ex          Y      SBrkr
# 663        1392         1392    GasA        Gd          Y      SBrkr
# 261           0         1362    GasA        TA          Y      SBrkr
# 1011        720          720    GasA        TA          Y      SBrkr
# 855         372         1763    GasA        TA          Y      SBrkr
#
#       1stFlrSF  LowQualFinSF  GrLivArea  BsmtFullBath  BsmtHalfBath  FullBath  \
# Id
# 1016    1665.0             0     1665.0             1             0         2
# 1239    1141.0             0     1141.0             0             0         1
# 663     1392.0             0     1392.0             1             0         1
# 261     1382.0             0     1382.0             1             0         1
# 1011    1271.0             0     1271.0             0             0         2
# 855     1779.0             0     1779.0             1             0         1
#
#       HalfBath  BedroomAbvGr  KitchenAbvGr KitchenQual  TotRmsAbvGrd  \
# Id
# 1016         1             3             1          Gd             6
# 1239         1             3             1          TA             6
# 663          0             2             1          TA             5
# 261          0             3             1          TA             6
# 1011         0             4             1          TA             7
# 855          1             3             1          TA             6
#
#      Functional  Fireplaces FireplaceQu GarageType  GarageYrBlt GarageFinish  \
# Id
# 1016        Typ           0        None     Attchd       2001.0          Fin
# 1239        Typ           0        None     Detchd       2005.0          Unf
# 663        Maj2           2          TA     Attchd       1968.0          RFn
# 261         Typ           1          TA     Attchd       1991.0          Unf
# 1011        Typ           1          Gd     Attchd       1948.0          Unf
# 855         Typ           1          Gd     Attchd       1955.0          Unf
#
#       GarageCars  GarageArea GarageQual GarageCond PavedDrive  WoodDeckSF  \
# Id
# 1016           2         528         TA         TA          Y           0
# 1239           2         484         TA         TA          Y           0
# 663            2         576         TA         TA          Y           0
# 261            2         884         TA         TA          Y           0
# 1011           1         312         TA         TA          Y           0
# 855            2         454         TA         TA          Y           0
#
#       OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea PoolQC  \
# Id
# 1016           45              0          0            0         0   None
# 1239            0              0          0            0         0   None
# 663             0            240          0            0         0   None
# 261             0            252          0            0         0   None
# 1011            0            108          0            0         0   None
# 855           418              0          0          312         0   None
#
#      Fence MiscFeature  MiscVal  MoSold  YrSold SaleType SaleCondition  \
# Id
# 1016  None        None        0      11    2009       WD        Normal
# 1239  None        None        0       3    2006       WD       Abnorml
# 663   None        None        0       7    2009       WD        Normal
# 261   GdWo        None        0       5    2009       WD        Normal
# 1011  None        None        0       8    2008       WD        Normal
# 855   None        None        0       7    2006       WD       Abnorml
#
#       SalePrice  no_of_fl
# Id
# 1016  12.332705         2
# 1239  11.867097         1
# 663   11.608236         1
# 261   12.078239         1
# 1011  11.813030         2
# 855   12.043554         1
